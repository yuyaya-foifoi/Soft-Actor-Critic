# %%
cd drive/MyDrive/JAIST/Research/RL/meta_exp

# %%
# !make env_setup

# %%
from src.agents.sac import SAC
from src.utils.trainer import get_trainer

algo = SAC(device='cuda:0', lr=1e-3, alpha=0.002, tau=0.1)
trainer = get_trainer()
trainer.fit(algo)
